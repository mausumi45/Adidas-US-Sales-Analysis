# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Datasets

# %%
data = pd.read_excel("Adidas US Sales Datasets.xlsx", skiprows = 4)
data.drop("Unnamed: 0", axis = 1,inplace = True )
data
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# ### Shape ,size  & Dimension of dataset

# %%
data.shape
# Out:
# (9648, 13)

# %%
data.size
# Out:
# 125424

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# ### Renaming the column

# %%
data = data.rename(columns = {'Units Sold' : 'Quantity', 'Operating Profit' : 'Profit', 'Operating Margin' : 'Margin'})
data
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Quantity  \
# ...

# %% [markdown]
# ### Datatype of columns

# %%
data.dtypes
# Out:
# Retailer                  object
# Retailer ID                int64
# Invoice Date      datetime64[ns]
# Region                    object
# State                     object
# City                      object
# Product                   object
# Price per Unit           float64
# Quantity                   int64
# Total Sales              float64
# Profit                   float64
# Margin                   float64
# Sales Method              object
# dtype: object

# %% [markdown]
# ### Extracted month name and year column from invoice date

# %%
data['month'] = data['Invoice Date'].dt.month_name()
data['year'] = data['Invoice Date'].dt.year

# %%
data
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Quantity  \
# ...

# %% [markdown]
# ### Missing Values

# %%
data.isnull().sum()
# Out:
# Retailer          0
# Retailer ID       0
# Invoice Date      0
# Region            0
# State             0
# City              0
# Product           0
# Price per Unit    0
# Quantity          0
# Total Sales       0
# Profit            0
# Margin            0
# Sales Method      0
# month             0
# year              0
# dtype: int64

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# ### Correlation Analysis

# %%
sns.heatmap(data.corr(), cmap="crest", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####  Quantity, Total sales and profits are highly correlated to each other.

# %% [markdown]
# ### Regionwise top selling & profitable Product

# %%
Region_top_prod = data.groupby(['Region','Product'])['Total Sales','Profit'].sum()
Region_top_prod['sales_rank'] = Region_top_prod.groupby('Region')['Total Sales'].rank(ascending = False)
Region_top_prod['profit_rank'] = Region_top_prod.groupby('Region')['Profit'].rank(ascending = False)
Region_top_prod = Region_top_prod.loc[(Region_top_prod['sales_rank'] == 1.0) & (Region_top_prod['profit_rank'] == 1.0)].reset_index()
Region_top_prod
# Out:
#       Region                Product  Total Sales       Profit  sales_rank  \
# 0    Midwest  Men's Street Footwear   38322810.0  14997372.71         1.0
# 1  Northeast  Men's Street Footwear   51025024.0  21356317.22         1.0
# 2      South        Women's Apparel   29607187.0  14655080.77         1.0
# 3  Southeast  Men's Street Footwear   36019236.0  14622841.99         1.0
# 4       West  Men's Street Footwear   55014613.0  20317868.04         1.0
#
#    profit_rank
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(x='Region', y='Total Sales', hue='Product', data = data, palette='Set2')
plt.title('Top Selling and Profitable Products by Region', fontsize = 20)
plt.xlabel('Region')
plt.ylabel('Sales (in thousands)')
plt.show()

# %% [markdown]
# #### Men's Street Footware is the most profitable product in every region of US .
# #### The highest sales of men's Footware occured in southern region.

# %% [markdown]
# ### Top 5 Profitable state

# %%
Top_5_state = data.groupby('State')['Profit'].sum().sort_values(ascending = False).reset_index()
Top_5_state = Top_5_state[['State', 'Profit']].head(5)
Top_5_state
# Out:
#             State       Profit
# 0        New York  23329824.07
# 1         Florida  20926206.92
# 2      California  19301170.40
# 3           Texas  18688204.35
# 4  South Carolina  11324236.39

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(x='Profit', y='State', data=Top_5_state, palette='YlOrBr')
plt.title('Top 5 Profitable States', fontsize = 20)
plt.xlabel('Profit (in thousands)')
plt.ylabel('State')
plt.show()

# %% [markdown]
# #### Newyork was the most profitable city.

# %% [markdown]
# ### Bottom 5 Profitable state

# %%
Bottom_5_state = data.groupby('State')['Profit'].sum().sort_values(ascending = True).reset_index()
Bottom_5_state = Bottom_5_state[['State', 'Profit']].head(5)
Bottom_5_state
# Out:
#           State      Profit
# 0      Nebraska  2439478.41
# 1          Iowa  2655217.37
# 2     Minnesota  2670229.76
# 3  North Dakota  2688519.72
# 4      Maryland  2757642.12

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.barplot(x='Profit', y='State', data=Bottom_5_state, palette='cubehelix')
plt.title('Bottom 5 Profitable States', fontsize = 20)
plt.xlabel('Profit (in thousands)')
plt.ylabel('State')
plt.show()

# %% [markdown]
# #### - Nebraska was the lowest profitable state.

# %% [markdown]
# ### Top 5 Profitable city

# %%
Top_5_City = data.groupby('City')['Profit'].sum().sort_values(ascending = False).reset_index()
Top_5_City = Top_5_City[['City', 'Profit']].head(5)
Top_5_City
# Out:
#             City       Profit
# 0     Charleston  15607190.11
# 1       New York  13899973.16
# 2          Miami  12168619.11
# 3       Portland  10760799.37
# 4  San Francisco  10256249.56

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.barplot(data=Top_5_City, x="City", y="Profit", palette = 'mako')
plt.title('Top 5 Profitable States', fontsize = 20)
plt.xlabel('Profit')
plt.ylabel('City')
plt.show()

# %% [markdown]
# #### -Most Profitable city was Charleston.

# %% [markdown]
# ### Monthwise profit  & quantity anlysis

# %%
Monthwise_profit = data.groupby('month')['Profit', 'Quantity'].sum()
Monthwise_profit
# Out:
#                 Profit  Quantity
# month
# April      27559237.31    216426
# August     34451440.30    257721
# December   31590202.03    191791
# February   21392736.70    193959
# January    25141934.51    227632
# July       34054898.59    218700
# June       26714715.92    181014
# March      20439788.00    190960
# May        29946255.33    214605
# November   24755521.43    174502
# October    25078444.60    183001
# September  31009586.73    228550

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.lineplot(x='month', y='Profit', data=Monthwise_profit, color='blue', label = 'Profit')
plt.title('Month-wise Profit Analysis', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# #### - Most Profitable month was august  and least profitable month was march.

# %% [markdown]
# ### Yearwise profit analysis product wise

# %%
yearwise_product_profit = data.groupby(['year', 'Product'])['Profit'].sum().reset_index()
yearwise_product_profit
# Out:
#     year                    Product       Profit
# 0   2020              Men's Apparel   9660070.37
# 1   2020    Men's Athletic Footwear   9359256.91
# 2   2020      Men's Street Footwear  15558837.44
# 3   2020            Women's Apparel  11302905.22
# 4   2020  Women's Athletic Footwear   8290741.17
# 5   2020    Women's Street Footwear   9203851.47
# 6   2021              Men's Apparel  35102959.96
# 7   2021    Men's Athletic Footwear  42487631.28
# 8   2021      Men's Street Footwear  67243423.18
# 9   2021            Women's Apparel  57348065.34
# 10  2021  Women's Athletic Footwear  30685043.77
# 11  2021    Women's Street Footwear  35891975.34

# %%
df_pivot = yearwise_product_profit.pivot_table(index='Product', columns='year', values='Profit')
sns.set(rc={'figure.figsize':(20,10)})
df_pivot.plot(kind='bar', stacked=True)

plt.title('Product-wise Profit Analysis in Each Year', fontsize = 20)
plt.xlabel('Product')
plt.ylabel('Profit')
plt.legend(title='Year')
plt.show()

# %% [markdown]
# #### - Men's Street Footware was the most selling product in 2021 and 2020.
# #### - Women's Athletic Footware was the least selling product .

# %% [markdown]
# ### Top profitable product in each sales method

# %%
methodwise_profitable_prod = data.groupby(['Sales Method','Product'])['Profit'].sum().reset_index()
methodwise_profitable_prod['rank'] = methodwise_profitable_prod.groupby('Sales Method')['Profit'].rank(ascending = False)
methodwise_profitable_prod.loc[methodwise_profitable_prod['rank'] == 1.0]
# Out:
#    Sales Method                Product       Profit  rank
# 2      In-store  Men's Street Footwear  34867100.00   1.0
# 8        Online  Men's Street Footwear  22958021.76   1.0
# 14       Outlet  Men's Street Footwear  24977138.86   1.0

# %% [markdown]
# ### Productwise margin analysis

# %%
prod_margin = data.groupby('Product')['Margin'].mean().reset_index()
prod_margin = prod_margin.sort_values(by = 'Margin',ascending = False)
prod_margin
# Out:
#                      Product    Margin
# 2      Men's Street Footwear  0.446130
# 3            Women's Apparel  0.441318
# 4  Women's Athletic Footwear  0.424359
# 0              Men's Apparel  0.413225
# 5    Women's Street Footwear  0.410199
# 1    Men's Athletic Footwear  0.402702

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.set_palette('Spectral')
plt.pie(prod_margin['Margin'], labels=prod_margin['Product'], autopct='%1.1f%%')
plt.title('Product-wise Margin Analysis', fontsize = 15)
plt.show()

# %% [markdown]
# ### Yearwise retailer sales analysis

# %%
retailer_sales = data.groupby(['Retailer','year'])['Total Sales'].mean().reset_index()
retailer_sales
# Out:
#          Retailer  year    Total Sales
# 0          Amazon  2021   81874.512118
# 1     Foot Locker  2020  127230.875371
# 2     Foot Locker  2021   77051.267391
# 3          Kohl's  2020   94812.875000
# 4          Kohl's  2021   99174.412916
# 5   Sports Direct  2020  143972.650943
# 6   Sports Direct  2021   86817.183801
# 7         Walmart  2020  152245.370370
# 8         Walmart  2021  101642.463415
# 9       West Gear  2020  142203.568504
# 10      West Gear  2021   87788.997700

# %%
retailer_sales = retailer_sales.set_index('Retailer')
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(x=retailer_sales.index, y='Total Sales', hue='year', data=retailer_sales, palette='rocket')
plt.title('Year-wise Retailer Sales Analysis')
plt.xlabel('Retailer')
plt.ylabel('Sales')
plt.legend(title='Year')
plt.show()

# %% [markdown]
# ### Quarterly sales analysis by each retailer

# %%
data['quarter'] = pd.PeriodIndex(data['Invoice Date'], freq = 'Q')
data
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Quantity  \
# ...

# %%
quarterly_sales_retailer = data.groupby(['Retailer','quarter'])['Total Sales'].sum().reset_index()
quarterly_sales_retailer['rank'] = quarterly_sales_retailer.groupby('Retailer')['Total Sales'].rank(ascending = False)
quarterly_sales_retailer = quarterly_sales_retailer.loc[quarterly_sales_retailer['rank'] == 1.0]
quarterly_sales_retailer
# Out:
#          Retailer quarter  Total Sales  rank
# 3          Amazon  2021Q4   25262647.0   1.0
# 11    Foot Locker  2021Q4   53822821.0   1.0
# 14         Kohl's  2021Q2   35612857.0   1.0
# 22  Sports Direct  2021Q3   59820169.0   1.0
# 29        Walmart  2021Q3   20294689.0   1.0
# 35      West Gear  2021Q1   44638872.0   1.0

# %%
sns.set(rc={'figure.figsize':(20,15)})
sns.color_palette("viridis", as_cmap=True)
sns.barplot(x='Retailer', y='Total Sales', hue='quarter', data=data)
plt.title('Quarterly Sales by Retailer')
plt.xlabel('Retailer')
plt.ylabel('Sales (in thousands)')
plt.show()
